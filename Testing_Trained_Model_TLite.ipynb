# %%
import os
import time
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf

class ImageSplicer:
    """Class to handle image splicing."""
    
    def __init__(self, file_path, n):
        self.file_path = file_path
        self.n = n

    def splice_image(self):
        """Splices the image into n x n tiles."""
        img = Image.open(self.file_path)
        width, height = img.size
        tile_width = width // self.n
        tile_height = height // self.n
        cropped_images = []

        for i in range(self.n):
            for j in range(self.n):
                left = j * tile_width
                upper = i * tile_height
                right = left + tile_width
                lower = upper + tile_height
                cropped_img = img.crop((left, upper, right, lower))
                cropped_images.append((cropped_img, i * self.n + j))  # Store image along with index

        return cropped_images

class CloudMasker:
    """Class to handle cloud masking and inpainting."""
    
    def __init__(self, t1=0.1, t2=0.1, kernel_size=10, inpaint_radius=5):
        self.t1 = t1
        self.t2 = t2
        self.kernel_size = kernel_size
        self.inpaint_radius = inpaint_radius

    def mask_clouds(self, image):
        """Masks the clouds in an image and inpaints the masked regions."""
        image = np.array(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        R = image[:, :, 2].astype(float)
        G = image[:, :, 1].astype(float)
        B = image[:, :, 0].astype(float)
        rg = R / G
        gb = G / B

        cloud_mask1 = np.logical_and(np.abs(rg - 1) < self.t1, np.abs(gb - 1) < self.t2).astype(np.uint8)
        cloud_mask = cv2.dilate(cloud_mask1, kernel=np.ones((self.kernel_size, self.kernel_size), dtype=np.uint8), iterations=1)
        
        R_inpaint = cv2.inpaint(R.astype(np.uint8), cloud_mask, self.inpaint_radius, cv2.INPAINT_TELEA)
        G_inpaint = cv2.inpaint(G.astype(np.uint8), cloud_mask, self.inpaint_radius, cv2.INPAINT_TELEA)
        B_inpaint = cv2.inpaint(B.astype(np.uint8), cloud_mask, self.inpaint_radius, cv2.INPAINT_TELEA)
        
        inpainted_image = np.stack([B_inpaint, G_inpaint, R_inpaint], axis=2)
        cloud_cover = np.sum(cloud_mask) / cloud_mask.size * 100

        # Print cloud cover percentage
        print(f"Cloud cover: {cloud_cover:.2f}%")

        return cloud_cover, Image.fromarray(inpainted_image)

class ImageProcessor:
    """Main class to process images."""
    
    def __init__(self, image_path, tflite_model_path, n=3, threshold=20):
        self.image_path = image_path
        self.tflite_model_path = tflite_model_path
        self.n = n
        self.threshold = threshold
        self.interpreter = self._load_tflite_model()

    def _load_tflite_model(self):
        """Loads the TensorFlow Lite model."""
        interpreter = tf.lite.Interpreter(model_path=self.tflite_model_path)
        interpreter.allocate_tensors()
        return interpreter

    def _predict_with_tflite(self, image):
        """Predicts the class of an image using the TensorFlow Lite model."""
        input_details = self.interpreter.get_input_details()[0]
        output_details = self.interpreter.get_output_details()[0]

        image = cv2.resize(np.array(image), (IMG_WIDTH, IMG_HEIGHT))
        image = np.expand_dims(image, axis=0).astype(np.float32)
        
        self.interpreter.set_tensor(input_details['index'], image)
        self.interpreter.invoke()
        predictions = self.interpreter.get_tensor(output_details['index'])
        return np.argmax(predictions)

    def process_images(self):
        """
        Processes the images by splicing, masking, and predicting.
        - Splices the image into tiles
        - Masks clouds and filters tiles based on cloud cover
        - Predicts the class of each filtered tile
        """
        start_time = time.time()  # Record start time
        
        splicer = ImageSplicer(self.image_path, self.n)
        images = splicer.splice_image()

        masker = CloudMasker()
        if not os.path.exists(FILTERED_IMAGE_FOLDER):
            os.makedirs(FILTERED_IMAGE_FOLDER)

        base_name = os.path.splitext(os.path.basename(self.image_path))[0]
        for cropped_img, idx in images:
            cloud_cover, inpainted_image = masker.mask_clouds(cropped_img)
            
            status = "Accepted" if cloud_cover < self.threshold else "Rejected"
            print(f"Part {idx} Cloud Coverage: {cloud_cover:.2f}% - {status}")
            
            if cloud_cover < self.threshold:
                # Resize for model processing
                downgraded_img = inpainted_image.resize((IMG_WIDTH, IMG_HEIGHT), Image.LANCZOS)
                img_array = np.array(downgraded_img) / 255.0
                img_array_exp = np.expand_dims(img_array, axis=0)
                prediction = self._predict_with_tflite(downgraded_img)
                
                predicted_class = prediction
                print(f"Predicted class index: {predicted_class}")

                # Check if the predicted class indicates vegetation (class index 1)
                if predicted_class == 1:
                    class_folder = FILTERED_IMAGE_FOLDER
                    os.makedirs(class_folder, exist_ok=True)
                    output_name = f"{base_name}_Q{idx}.png"
                    output_path = os.path.join(class_folder, output_name)
                    
                    # Save the original, high-resolution quadrant
                    cropped_img.save(output_path)
                    print(f"Original high-resolution quadrant saved to {output_path}")

                    # Plotting original, masked, and inpainted images
                    self._plot_images(cropped_img, inpainted_image, cloud_cover, predicted_class, idx)
        
        end_time = time.time()  # Record end time
        elapsed_time = end_time - start_time
        print(f"Time taken for processing: {elapsed_time:.2f} seconds")


FILTERED_IMAGE_FOLDER = r'C:\Users\abudh\Desktop\CropWatch\Filtered_Image'
TFLITE_MODEL_PATH = r'C:\Users\abudh\Desktop\CropWatch\resnet50_veg.tflite'
TILE_COUNT = 3
THRESHOLD_PERCENTAGE = 20
IMG_WIDTH = 64  # Define image width for model input
IMG_HEIGHT = 64  # Define image height for model input
TEST_FOLDER = r'C:\Users\abudh\Desktop\CropWatch\Test4'  # Add this configuration # Processing and visualizing images
start_time = time.time()  # Record start time for the entire processing

for image_file in os.listdir(TEST_FOLDER):
    image_path = os.path.join(TEST_FOLDER, image_file)
    image_processor = ImageProcessor(image_path, TFLITE_MODEL_PATH, n=TILE_COUNT, threshold=THRESHOLD_PERCENTAGE)
    image_processor.process_images()

end_time = time.time()  # Record end time for the entire processing
total_elapsed_time = end_time - start_time
print(f"Total time taken for all images: {total_elapsed_time:.2f} seconds")
# Out:
# Cloud cover: 98.27%
# Part 0 Cloud Coverage: 98.27% - Rejected
# Cloud cover: 99.10%
# Part 1 Cloud Coverage: 99.10% - Rejected
# Cloud cover: 99.94%
# Part 2 Cloud Coverage: 99.94% - Rejected
# Cloud cover: 99.82%
# Part 3 Cloud Coverage: 99.82% - Rejected
# Cloud cover: 100.00%
# Part 4 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 99.99%
# Part 5 Cloud Coverage: 99.99% - Rejected
# Cloud cover: 99.99%
# Part 6 Cloud Coverage: 99.99% - Rejected
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 99.98%
# Part 8 Cloud Coverage: 99.98% - Rejected
# Time taken for processing: 137.58 seconds
# Cloud cover: 21.25%
# Part 0 Cloud Coverage: 21.25% - Rejected
# Cloud cover: 10.97%
# Part 1 Cloud Coverage: 10.97% - Accepted
# Predicted class index: 0
# Cloud cover: 11.94%
# Part 2 Cloud Coverage: 11.94% - Accepted
# Predicted class index: 0
# Cloud cover: 11.75%
# Part 3 Cloud Coverage: 11.75% - Accepted
# Predicted class index: 0
# Cloud cover: 17.62%
# Part 4 Cloud Coverage: 17.62% - Accepted
# Predicted class index: 0
# Cloud cover: 23.51%
# Part 5 Cloud Coverage: 23.51% - Rejected
# Cloud cover: 4.50%
# Part 6 Cloud Coverage: 4.50% - Accepted
# Predicted class index: 0
# Cloud cover: 5.88%
# Part 7 Cloud Coverage: 5.88% - Accepted
# Predicted class index: 0
# Cloud cover: 15.04%
# Part 8 Cloud Coverage: 15.04% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.22 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.14 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Cloud cover: 16.33%
# Part 0 Cloud Coverage: 16.33% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.12 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.12 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.12 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 32.43%
# Part 2 Cloud Coverage: 32.43% - Rejected
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 65.31%
# Part 4 Cloud Coverage: 65.31% - Rejected
# Cloud cover: 29.71%
# Part 5 Cloud Coverage: 29.71% - Rejected
# Cloud cover: 11.34%
# Part 6 Cloud Coverage: 11.34% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.09 seconds
# Cloud cover: 10.20%
# Part 0 Cloud Coverage: 10.20% - Accepted
# Predicted class index: 0
# Cloud cover: 47.62%
# Part 1 Cloud Coverage: 47.62% - Rejected
# Cloud cover: 100.00%
# Part 2 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 3 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 4 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 5 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 6 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 8 Cloud Coverage: 100.00% - Rejected
# Time taken for processing: 0.03 seconds
# Cloud cover: 98.41%
# Part 0 Cloud Coverage: 98.41% - Rejected
# Cloud cover: 100.00%
# Part 1 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 90.25%
# Part 2 Cloud Coverage: 90.25% - Rejected
# Cloud cover: 89.34%
# Part 3 Cloud Coverage: 89.34% - Rejected
# Cloud cover: 94.78%
# Part 4 Cloud Coverage: 94.78% - Rejected
# Cloud cover: 100.00%
# Part 5 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 82.31%
# Part 6 Cloud Coverage: 82.31% - Rejected
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 8 Cloud Coverage: 100.00% - Rejected
# Time taken for processing: 0.02 seconds
# Cloud cover: 72.79%
# Part 0 Cloud Coverage: 72.79% - Rejected
# Cloud cover: 72.34%
# Part 1 Cloud Coverage: 72.34% - Rejected
# Cloud cover: 89.57%
# Part 2 Cloud Coverage: 89.57% - Rejected
# Cloud cover: 100.00%
# Part 3 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 4 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 94.33%
# Part 5 Cloud Coverage: 94.33% - Rejected
# Cloud cover: 78.23%
# Part 6 Cloud Coverage: 78.23% - Rejected
# Cloud cover: 78.68%
# Part 7 Cloud Coverage: 78.68% - Rejected
# Cloud cover: 65.08%
# Part 8 Cloud Coverage: 65.08% - Rejected
# Time taken for processing: 0.02 seconds
# Cloud cover: 100.00%
# Part 0 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 1 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 2 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 99.55%
# Part 3 Cloud Coverage: 99.55% - Rejected
# Cloud cover: 100.00%
# Part 4 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 5 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 6 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 8 Cloud Coverage: 100.00% - Rejected
# Time taken for processing: 0.00 seconds
# Cloud cover: 54.42%
# Part 0 Cloud Coverage: 54.42% - Rejected
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 24.72%
# Part 3 Cloud Coverage: 24.72% - Rejected
# Cloud cover: 31.29%
# Part 4 Cloud Coverage: 31.29% - Rejected
# Cloud cover: 59.18%
# Part 5 Cloud Coverage: 59.18% - Rejected
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 8 Cloud Coverage: 100.00% - Rejected
# Time taken for processing: 0.06 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 20.18%
# Part 2 Cloud Coverage: 20.18% - Rejected
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 47.17%
# Part 8 Cloud Coverage: 47.17% - Rejected
# Time taken for processing: 0.09 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.12 seconds
# Cloud cover: 30.16%
# Part 0 Cloud Coverage: 30.16% - Rejected
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 65.53%
# Part 2 Cloud Coverage: 65.53% - Rejected
# Cloud cover: 54.42%
# Part 3 Cloud Coverage: 54.42% - Rejected
# Cloud cover: 51.70%
# Part 4 Cloud Coverage: 51.70% - Rejected
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 32.88%
# Part 6 Cloud Coverage: 32.88% - Rejected
# Cloud cover: 14.97%
# Part 7 Cloud Coverage: 14.97% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.08 seconds
# Cloud cover: 90.48%
# Part 0 Cloud Coverage: 90.48% - Rejected
# Cloud cover: 45.80%
# Part 1 Cloud Coverage: 45.80% - Rejected
# Cloud cover: 15.87%
# Part 2 Cloud Coverage: 15.87% - Accepted
# Predicted class index: 0
# Cloud cover: 82.31%
# Part 3 Cloud Coverage: 82.31% - Rejected
# Cloud cover: 20.41%
# Part 4 Cloud Coverage: 20.41% - Rejected
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 23.58%
# Part 6 Cloud Coverage: 23.58% - Rejected
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.07 seconds
# Cloud cover: 19.73%
# Part 0 Cloud Coverage: 19.73% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 23.81%
# Part 2 Cloud Coverage: 23.81% - Rejected
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 43.31%
# Part 5 Cloud Coverage: 43.31% - Rejected
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 23.81%
# Part 7 Cloud Coverage: 23.81% - Rejected
# Cloud cover: 53.06%
# Part 8 Cloud Coverage: 53.06% - Rejected
# Time taken for processing: 0.08 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 6.80%
# Part 3 Cloud Coverage: 6.80% - Accepted
# Predicted class index: 0
# Cloud cover: 8.16%
# Part 4 Cloud Coverage: 8.16% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 17.01%
# Part 6 Cloud Coverage: 17.01% - Accepted
# Predicted class index: 0
# Cloud cover: 63.95%
# Part 7 Cloud Coverage: 63.95% - Rejected
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.16 seconds
# Cloud cover: 96.60%
# Part 0 Cloud Coverage: 96.60% - Rejected
# Cloud cover: 65.53%
# Part 1 Cloud Coverage: 65.53% - Rejected
# Cloud cover: 96.15%
# Part 2 Cloud Coverage: 96.15% - Rejected
# Cloud cover: 86.62%
# Part 3 Cloud Coverage: 86.62% - Rejected
# Cloud cover: 74.38%
# Part 4 Cloud Coverage: 74.38% - Rejected
# Cloud cover: 38.10%
# Part 5 Cloud Coverage: 38.10% - Rejected
# Cloud cover: 84.81%
# Part 6 Cloud Coverage: 84.81% - Rejected
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 8 Cloud Coverage: 100.00% - Rejected
# Time taken for processing: 0.02 seconds
# Cloud cover: 64.85%
# Part 0 Cloud Coverage: 64.85% - Rejected
# Cloud cover: 36.28%
# Part 1 Cloud Coverage: 36.28% - Rejected
# Cloud cover: 89.12%
# Part 2 Cloud Coverage: 89.12% - Rejected
# Cloud cover: 56.01%
# Part 3 Cloud Coverage: 56.01% - Rejected
# Cloud cover: 76.64%
# Part 4 Cloud Coverage: 76.64% - Rejected
# Cloud cover: 87.98%
# Part 5 Cloud Coverage: 87.98% - Rejected
# Cloud cover: 91.84%
# Part 6 Cloud Coverage: 91.84% - Rejected
# Cloud cover: 48.53%
# Part 7 Cloud Coverage: 48.53% - Rejected
# Cloud cover: 70.29%
# Part 8 Cloud Coverage: 70.29% - Rejected
# Time taken for processing: 0.02 seconds
# Cloud cover: 98.41%
# Part 0 Cloud Coverage: 98.41% - Rejected
# Cloud cover: 100.00%
# Part 1 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 2 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 95.01%
# Part 3 Cloud Coverage: 95.01% - Rejected
# Cloud cover: 100.00%
# Part 4 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 5 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 97.96%
# Part 6 Cloud Coverage: 97.96% - Rejected
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 8 Cloud Coverage: 100.00% - Rejected
# Time taken for processing: 0.02 seconds
# Cloud cover: 100.00%
# Part 0 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 96.83%
# Part 1 Cloud Coverage: 96.83% - Rejected
# Cloud cover: 98.41%
# Part 2 Cloud Coverage: 98.41% - Rejected
# Cloud cover: 99.09%
# Part 3 Cloud Coverage: 99.09% - Rejected
# Cloud cover: 95.24%
# Part 4 Cloud Coverage: 95.24% - Rejected
# Cloud cover: 82.77%
# Part 5 Cloud Coverage: 82.77% - Rejected
# Cloud cover: 100.00%
# Part 6 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 8 Cloud Coverage: 100.00% - Rejected
# Time taken for processing: 0.00 seconds
# Cloud cover: 97.28%
# Part 0 Cloud Coverage: 97.28% - Rejected
# Cloud cover: 95.69%
# Part 1 Cloud Coverage: 95.69% - Rejected
# Cloud cover: 100.00%
# Part 2 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 93.65%
# Part 3 Cloud Coverage: 93.65% - Rejected
# Cloud cover: 100.00%
# Part 4 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 97.51%
# Part 5 Cloud Coverage: 97.51% - Rejected
# Cloud cover: 100.00%
# Part 6 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 94.78%
# Part 7 Cloud Coverage: 94.78% - Rejected
# Cloud cover: 70.07%
# Part 8 Cloud Coverage: 70.07% - Rejected
# Time taken for processing: 0.02 seconds
# Cloud cover: 98.87%
# Part 0 Cloud Coverage: 98.87% - Rejected
# Cloud cover: 88.44%
# Part 1 Cloud Coverage: 88.44% - Rejected
# Cloud cover: 93.42%
# Part 2 Cloud Coverage: 93.42% - Rejected
# Cloud cover: 85.03%
# Part 3 Cloud Coverage: 85.03% - Rejected
# Cloud cover: 95.46%
# Part 4 Cloud Coverage: 95.46% - Rejected
# Cloud cover: 73.47%
# Part 5 Cloud Coverage: 73.47% - Rejected
# Cloud cover: 96.60%
# Part 6 Cloud Coverage: 96.60% - Rejected
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 70.07%
# Part 8 Cloud Coverage: 70.07% - Rejected
# Time taken for processing: 0.02 seconds
# Cloud cover: 63.04%
# Part 0 Cloud Coverage: 63.04% - Rejected
# Cloud cover: 24.94%
# Part 1 Cloud Coverage: 24.94% - Rejected
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 94.33%
# Part 3 Cloud Coverage: 94.33% - Rejected
# Cloud cover: 93.20%
# Part 4 Cloud Coverage: 93.20% - Rejected
# Cloud cover: 77.32%
# Part 5 Cloud Coverage: 77.32% - Rejected
# Cloud cover: 73.70%
# Part 6 Cloud Coverage: 73.70% - Rejected
# Cloud cover: 80.50%
# Part 7 Cloud Coverage: 80.50% - Rejected
# Cloud cover: 21.77%
# Part 8 Cloud Coverage: 21.77% - Rejected
# Time taken for processing: 0.03 seconds
# Cloud cover: 13.61%
# Part 0 Cloud Coverage: 13.61% - Accepted
# Predicted class index: 0
# Cloud cover: 79.37%
# Part 1 Cloud Coverage: 79.37% - Rejected
# Cloud cover: 100.00%
# Part 2 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 83.67%
# Part 3 Cloud Coverage: 83.67% - Rejected
# Cloud cover: 55.78%
# Part 4 Cloud Coverage: 55.78% - Rejected
# Cloud cover: 95.46%
# Part 5 Cloud Coverage: 95.46% - Rejected
# Cloud cover: 93.42%
# Part 6 Cloud Coverage: 93.42% - Rejected
# Cloud cover: 92.97%
# Part 7 Cloud Coverage: 92.97% - Rejected
# Cloud cover: 55.10%
# Part 8 Cloud Coverage: 55.10% - Rejected
# Time taken for processing: 0.03 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.12 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Cloud cover: 100.00%
# Part 0 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 1 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 2 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 3 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 4 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 5 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 6 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 7 Cloud Coverage: 100.00% - Rejected
# Cloud cover: 100.00%
# Part 8 Cloud Coverage: 100.00% - Rejected
# Time taken for processing: 0.02 seconds
# Cloud cover: 0.00%
# Part 0 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 1 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 2 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 3 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 4 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 5 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 6 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 7 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Cloud cover: 0.00%
# Part 8 Cloud Coverage: 0.00% - Accepted
# Predicted class index: 0
# Time taken for processing: 0.13 seconds
# Total time taken for all images: 145.30 seconds
